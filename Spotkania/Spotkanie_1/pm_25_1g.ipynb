# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
dane = pd.read_excel('2018_PM25_1g.xlsx', skiprows = 5, index_col=0)
dane.head()
# Out:
#                     DsJelGorOgin-PM2.5-1g DsWrocAlWisn-PM2.5-1g  \
# Czas pomiaru
# 2018-01-01 01:00:00               43,0102                71,494
# 2018-01-01 02:00:00               5,38425               7,89305
# 2018-01-01 03:00:00               4,52882               12,5392
# 2018-01-01 04:00:00               8,68036               5,03196
# 2018-01-01 05:00:00                   7,2               11,9136
#
#                     DsWrocWybCon-PM2.5-1g KpBydPlPozna-PM2.5-1g  \
# Czas pomiaru
# 2018-01-01 01:00:00                  70,2               49,2716
# 2018-01-01 02:00:00               13,1522                36,236
# 2018-01-01 03:00:00                  12,5               14,7514
# 2018-01-01 04:00:00               8,85164               17,1654
# 2018-01-01 05:00:00               7,29656               12,5788
#
#                     KpBydWarszaw-PM2.5-1g KpToruDziewu-PM2.5-1g  \
# Czas pomiaru
# 2018-01-01 01:00:00               69,6873                18,778
# 2018-01-01 02:00:00               42,3178                   NaN
# 2018-01-01 03:00:00                   NaN                   NaN
# 2018-01-01 04:00:00                   NaN                13,353
# 2018-01-01 05:00:00                   NaN                   NaN
#
#                     KpWloclOkrze-PM2.5-1g LbLubObywate-PM2.5-1g  \
# Czas pomiaru
# 2018-01-01 01:00:00                   NaN                  30,9
# 2018-01-01 02:00:00                   NaN                  54,8
# 2018-01-01 03:00:00                   NaN                  24,3
# 2018-01-01 04:00:00                   NaN                  15,1
# 2018-01-01 05:00:00                   NaN                  12,6
#
#                     LdLodzCzerni-PM2.5-1g LdLodzGdansk-PM2.5-1g  ...  \
# Czas pomiaru                                                     ...
# 2018-01-01 01:00:00                  16,0                68,349  ...
# 2018-01-01 02:00:00                  83,0                39,999  ...
# 2018-01-01 03:00:00                  16,0                17,949  ...
# 2018-01-01 04:00:00                  14,0                12,699  ...
# 2018-01-01 05:00:00                  12,0                12,699  ...
#
#                     SkKonsGranatMOB-PM2.5-1g SkPolaRuszcz-PM2.5-1g  \
# Czas pomiaru
# 2018-01-01 01:00:00                      NaN                 27,68
# 2018-01-01 02:00:00                      NaN                 18,48
# 2018-01-01 03:00:00                      NaN                 15,59
# 2018-01-01 04:00:00                      NaN                 12,32
# 2018-01-01 05:00:00                      NaN                 10,03
#
#                     SlBielPartyz-PM2.5-1g SlKatoKossut-PM2.5-1g  \
# Czas pomiaru
# 2018-01-01 01:00:00                   NaN               76,8469
# 2018-01-01 02:00:00                   NaN               39,3395
# 2018-01-01 03:00:00                   NaN               23,2554
# 2018-01-01 04:00:00                   NaN               22,3614
# 2018-01-01 05:00:00                   NaN               28,9092
#
#                     SlZlotPotLes-PM2.5-1g WmOlsPuszkin-PM2.5-1g  \
# Czas pomiaru
# 2018-01-01 01:00:00               25,9266               41,3687
# 2018-01-01 02:00:00               32,7522               25,8502
# 2018-01-01 03:00:00               37,6664               22,4599
# 2018-01-01 04:00:00               32,4625               20,1625
# 2018-01-01 05:00:00                27,135               18,3681
#
#                     WpKaliSawick-PM2.5-1g WpPoznDabrow-PM2.5-1g  \
# Czas pomiaru
# 2018-01-01 01:00:00                   NaN                   NaN
# 2018-01-01 02:00:00                   NaN                   NaN
# 2018-01-01 03:00:00                   NaN                   NaN
# 2018-01-01 04:00:00                   NaN                   NaN
# 2018-01-01 05:00:00                   NaN                   NaN
#
#                     ZpSzczAndr01-PM2.5-1g ZpSzczPils02-PM2.5-1g
# Czas pomiaru
# 2018-01-01 01:00:00               26,5445               12,8035
# 2018-01-01 02:00:00                   NaN                   NaN
# 2018-01-01 03:00:00               10,4332               32,0944
# 2018-01-01 04:00:00               28,1885               27,3274
# 2018-01-01 05:00:00               40,1738               61,1957
#
# [5 rows x 51 columns]

# %%
dane.describe()
# Out:
#        DsJelGorOgin-PM2.5-1g DsWrocAlWisn-PM2.5-1g DsWrocWybCon-PM2.5-1g  \
# count                   8730                  8714                  8570
# unique                  8408                  8639                  7968
# top                     10,4                20,121                   6,4
# freq                       6                     2                    27
#
#        KpBydPlPozna-PM2.5-1g KpBydWarszaw-PM2.5-1g KpToruDziewu-PM2.5-1g  \
# count                   8422                  7228                  6605
# unique                  1001                  1327                  1038
# top                   8,9578                  10,6                 8,803
# freq                      51                    42                    50
#
#        KpWloclOkrze-PM2.5-1g LbLubObywate-PM2.5-1g LdLodzCzerni-PM2.5-1g  \
# count                   5797                  8673                  8641
# unique                   814                   854                   201
# top                     7,25                  11,0                 9,607
# freq                      38                    94                   274
#
#        LdLodzGdansk-PM2.5-1g  ... SkKonsGranatMOB-PM2.5-1g  \
# count                   8400  ...                     4158
# unique                   129  ...                      738
# top                   12,699  ...                     12,1
# freq                     301  ...                       23
#
#        SkPolaRuszcz-PM2.5-1g SlBielPartyz-PM2.5-1g SlKatoKossut-PM2.5-1g  \
# count                   8393                  8423                  8712
# unique                  4236                  8155                  8548
# top                      0,0               23,5754               28,4319
# freq                      32                     4                     3
#
#        SlZlotPotLes-PM2.5-1g WmOlsPuszkin-PM2.5-1g WpKaliSawick-PM2.5-1g  \
# count                   8263                  8207                  7552
# unique                  8049                  8096                  7464
# top                     15,0               5,16778                   7,8
# freq                       5                     3                     6
#
#        WpPoznDabrow-PM2.5-1g ZpSzczAndr01-PM2.5-1g ZpSzczPils02-PM2.5-1g
# count                   5595                  7201                  8704
# unique                  5491                  7149                  8519
# top                  9,42389               12,2911               14,0342
# freq                       3                     3                     3
#
# [4 rows x 51 columns]

# %%
waw = dane[['MzWarAlNiepo-PM2.5-1g','MzWarKondrat-PM2.5-1g', 'MzWarTolstoj-PM2.5-1g','MzWarWokalna-PM2.5-1g']]
waw.head()
# Out:
#                     MzWarAlNiepo-PM2.5-1g MzWarKondrat-PM2.5-1g  \
# Czas pomiaru
# 2018-01-01 01:00:00             52,514518              99,21228
# 2018-01-01 02:00:00             33,935946             33,262494
# 2018-01-01 03:00:00             28,653804             22,849369
# 2018-01-01 04:00:00             26,923446             21,609712
# 2018-01-01 05:00:00             25,193089             20,865917
#
#                     MzWarTolstoj-PM2.5-1g MzWarWokalna-PM2.5-1g
# Czas pomiaru
# 2018-01-01 01:00:00                 70,07                 65,47
# 2018-01-01 02:00:00                 22,44                 31,77
# 2018-01-01 03:00:00                 19,84                  25,2
# 2018-01-01 04:00:00                 19,04                 23,29
# 2018-01-01 05:00:00                 16,48                 20,71

# %%
waw.dtypes
# Out:
# MzWarAlNiepo-PM2.5-1g    object
# MzWarKondrat-PM2.5-1g    object
# MzWarTolstoj-PM2.5-1g    object
# MzWarWokalna-PM2.5-1g    object
# dtype: object

# %%
cols = ['MzWarAlNiepo-PM2.5-1g','MzWarKondrat-PM2.5-1g', 'MzWarTolstoj-PM2.5-1g','MzWarWokalna-PM2.5-1g']
waw[cols] = waw[cols].replace(',','.', regex=True).astype(float)
# Out:
# C:\Users\kamil\Anaconda3\lib\site-packages\pandas\core\frame.py:3489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
waw.dtypes
# Out:
# MzWarAlNiepo-PM2.5-1g    float64
# MzWarKondrat-PM2.5-1g    float64
# MzWarTolstoj-PM2.5-1g    float64
# MzWarWokalna-PM2.5-1g    float64
# dtype: object

# %%
waw.describe()
# Out:
#        MzWarAlNiepo-PM2.5-1g  MzWarKondrat-PM2.5-1g  MzWarTolstoj-PM2.5-1g  \
# count            8700.000000            8587.000000            8251.000000
# mean               24.855434              22.478208              23.327789
# std                17.304248              18.789784              17.447917
# min                 0.877018               1.031395               0.860000
# 25%                12.443089               9.956930              10.860000
# 50%                19.637732              17.022979              18.630000
# 75%                31.932375              28.427829              30.100000
# max               136.482375             256.028970             142.960000
#
#        MzWarWokalna-PM2.5-1g
# count            8530.000000
# mean               22.002741
# std                14.683713
# min                 3.280000
# 25%                11.240000
# 50%                18.065000
# 75%                28.195000
# max               118.890000

# %%
waw.isna().sum()
# Out:
# MzWarAlNiepo-PM2.5-1g     60
# MzWarKondrat-PM2.5-1g    173
# MzWarTolstoj-PM2.5-1g    509
# MzWarWokalna-PM2.5-1g    230
# dtype: int64

# %%
waw['MzWarAlNiepo-PM2.5-1g'].fillna(waw['MzWarAlNiepo-PM2.5-1g'].mean(), inplace=True)
waw['MzWarKondrat-PM2.5-1g'].fillna(waw['MzWarKondrat-PM2.5-1g'].mean(), inplace=True)
waw['MzWarTolstoj-PM2.5-1g'].fillna(waw['MzWarTolstoj-PM2.5-1g'].mean(), inplace=True)
waw['MzWarWokalna-PM2.5-1g'].fillna(waw['MzWarWokalna-PM2.5-1g'].mean(), inplace=True)
# Out:
# C:\Users\kamil\Anaconda3\lib\site-packages\pandas\core\generic.py:6288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %% [markdown]
# # Wykres liniowy

# %%
waw['MzWarAlNiepo-PM2.5-1g'].plot()
plt.xlabel('Czas pomiaru')
plt.ylabel(cols[0])
plt.legend()
plt.show()

# %%
waw['MzWarKondrat-PM2.5-1g'].plot()
plt.xlabel('Czas pomiaru')
plt.ylabel(cols[0])
plt.legend()
plt.show()

# %%
waw['MzWarTolstoj-PM2.5-1g'].plot()
plt.xlabel('Czas pomiaru')
plt.ylabel(cols[0])
plt.legend()
plt.show()

# %%
waw['MzWarWokalna-PM2.5-1g'].plot()
plt.xlabel('Czas pomiaru')
plt.ylabel(cols[0])
plt.legend()
plt.show()

# %% [markdown]
# # Histogram

# %%
waw.hist()
plt.show()

# %% [markdown]
# # Wykres pudełkowy

# %%
waw.boxplot()
plt.show()

# %% [markdown]
# # Wykres Q-Q

# %%
import pylab 
import scipy.stats as stats


stats.probplot(waw['MzWarAlNiepo-PM2.5-1g'], dist="norm", plot=pylab)

pylab.show()

# %%
stats.probplot(waw['MzWarKondrat-PM2.5-1g'], dist="norm", plot=pylab)
pylab.show()

# %%
stats.probplot(waw['MzWarTolstoj-PM2.5-1g'], dist="norm", plot=pylab)
pylab.show()

# %%
stats.probplot(waw['MzWarWokalna-PM2.5-1g'], dist="norm", plot=pylab)
pylab.show()

# %% [markdown]
# # Wykres rozrzutu dla wartości opóźnionych

# %%
from pandas.plotting import lag_plot

# %%
lag_plot(waw['MzWarAlNiepo-PM2.5-1g'], lag=1)
plt.title('MzWarAlNiepo-PM2.5-1g')
# Out:
# Text(0.5, 1.0, 'MzWarAlNiepo-PM2.5-1g')

# %%
lag_plot(waw['MzWarKondrat-PM2.5-1g'])
plt.title('MzWarKondrat-PM2.5-1g')
# Out:
# Text(0.5, 1.0, 'MzWarKondrat-PM2.5-1g')

# %%
lag_plot(waw['MzWarTolstoj-PM2.5-1g'])
plt.title('MzWarTolstoj-PM2.5-1g')
# Out:
# Text(0.5, 1.0, 'MzWarTolstoj-PM2.5-1g')

# %%
lag_plot(waw['MzWarWokalna-PM2.5-1g'])
plt.title('MzWarWokalna-PM2.5-1g')
# Out:
# Text(0.5, 1.0, 'MzWarWokalna-PM2.5-1g')

# %% [markdown]
# # Autokorelacja - FCA

# %%
from pandas.plotting import autocorrelation_plot

# %%
autocorrelation_plot(waw['MzWarAlNiepo-PM2.5-1g'])
plt.title('MzWarAlNiepo-PM2.5-1g')
# Out:
# Text(0.5, 1.0, 'MzWarAlNiepo-PM2.5-1g')

# %%
autocorrelation_plot(waw['MzWarKondrat-PM2.5-1g'])
plt.title('MzWarKondrat-PM2.5-1g')
# Out:
# Text(0.5, 1.0, 'MzWarKondrat-PM2.5-1g')

# %%
autocorrelation_plot(waw['MzWarTolstoj-PM2.5-1g'])
plt.title('MzWarTolstoj-PM2.5-1g')
# Out:
# Text(0.5, 1.0, 'MzWarTolstoj-PM2.5-1g')

# %%
autocorrelation_plot(waw['MzWarWokalna-PM2.5-1g'])
plt.title('MzWarWokalna-PM2.5-1g')
# Out:
# Text(0.5, 1.0, 'MzWarWokalna-PM2.5-1g')

# %% [markdown]
# # Dekompozycja

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

result = seasonal_decompose(waw['MzWarAlNiepo-PM2.5-1g'], model='multiplicative')
result.plot()
plt.show()

# %%
result = seasonal_decompose(waw['MzWarKondrat-PM2.5-1g'], model='multiplicative')
result.plot()
plt.show()

# %%
result = seasonal_decompose(waw['MzWarTolstoj-PM2.5-1g'], model='multiplicative')
result.plot()
plt.show()

# %%
result = seasonal_decompose(waw['MzWarWokalna-PM2.5-1g'], model='multiplicative')
result.plot()
plt.show()

# %% [markdown]
# # Test Dickeya-Fullera

# %%
from statsmodels.tsa.stattools import adfuller

X = waw['MzWarAlNiepo-PM2.5-1g'].values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -7.551776
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %%
Y = waw['MzWarKondrat-PM2.5-1g'].values
result = adfuller(Y)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -8.212581
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %%
Z = waw['MzWarTolstoj-PM2.5-1g'].values
result = adfuller(Z)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -8.652562
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %%
A = waw['MzWarWokalna-PM2.5-1g'].values
result = adfuller(A)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -7.593932
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
